# %% [markdown]
# 1. What is the concept of human learning? Please give two examples.

# %% [markdown]
# Answer:
#
# Human Learning is the acquisition of knowledge. The acquisition of knowledge can take the form of a behaviour, an education or a personal experience. There are two main types of Human Learning: visual learning, where we see things and then learn and remember them, and reading or writing based learning.

# %% [markdown]
# 2. What different forms of human learning are there? Are there any machine learning equivalents?

# %% [markdown]
# Answer:
#
# Following are the forms of human learning:
# 1)	Studying under supervision
# 2)	Studying without any supervision
#
# The machine learning equivalents of the above are supervised and unsupervised machine learning.

# %% [markdown]
# 3. What is machine learning, and how does it work? What are the key responsibilities of machine learning?

# %% [markdown]
# Answer:
#
# - Machine learning is the part of AI that trains computers to think like humans, for example, by Learning and learning from previous experiences.
# - The way it works is by giving the computer the ability to make predictions or aid in data analysis by building sophisticated algorithmic models which are trained to operate within the limits specified in the training data.
# - The key responsibilities of machine leaning are very specific to the domain/industry in which it operates.

# %% [markdown]
# 4. Define the terms "penalty" and "reward" in the context of reinforcement learning.

# %% [markdown]
# Answer:
#
# -> Penalty is similar to regularization term of logistic regression function which penalizes the overfitting and the underfitting. For example, in reinforcement learning, the training phase penalizes the algorithm with a penalty for every incorrect prediction or classification. In other words, the training phase sets the algorithm back one step.
#
# -> For every correct prediction/classification, the algorithm gains a reward. This means that the algorithm moves one step forward in making itself more efficient. There are hundreds of such iterations performed repeatedly to prepare the model.

# %% [markdown]
# 5. Explain the term "learning as a search"?

# %% [markdown]
# Answer:
#
# -> One way to think about learning is by searching through all the sentences in the concept description language to find the sentence that describes the data best. Another way is to think about learning as searching through all the hypotheses in the hypothesis space.
#
# -> In the case of concept learning, the challenge is to search through a large number of hypotheses that are implicitly defined by hypothesis representation.
#
# -> The challenge is to find a hypothesis that matches the training examples.

# %% [markdown]
# 6. What are the various goals of machine learning? What is the relationship between these and human learning?

# %% [markdown]
# Answer:
#
# The purpose of machine learning is to apply existing algorithms over data for the purpose of data analysis, exploration, visualisation and the generation of interpretable and general algorithmic models for the prediction of unseen data.
#
# The goal of machine learning, which is closely related to the goal of artificial intelligence, is to gain a better understanding of the nature of learning (human learning as well as other learning processes), computational aspects of learning behaviours and to implant learning capability in the computer system.
#
# Human beings have the capacity to learn. However, with the advancement of Artificial Intelligence, Machine Learning has become a tool that can supplement or even substitute human learning.
# Learning is not a process that happens all at once. It is a process that is built upon and shaped by prior knowledge.

# %% [markdown]
# 7. Illustrate the various elements of machine learning using a real-life illustration.

# %% [markdown]
# Answer:
#
# For example, a student learning for a mathematical exam may be a good example or illustration of this question. Below, a side by side comparison is made.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. Provide an example of the abstraction method.

# %% [markdown]
# Answer:
#
# In machine learning, feature selection reduces dimensionality by selecting only the most important and relevant features for our model to be more efficient, powerful and understandable. Removing irrelevant or insignificant features from a dataset is one of the examples of machine learning abstraction.

# %% [markdown]
# 9. What is the concept of generalization? What function does it play in the machine learning process?

# %% [markdown]
# Answer:
#
# Generalization is a term used in machine learning to describe how well a trained model learns to classify or predict unseen data. It refers to the model’s ability to adjust to new, unseen data that is derived from the same distribution as the data used to train the model. For example, a cat image may be classified as a dog if it is derived from an unseen dataset. Generating predictions based on data diversity is therefore very important. Generalization is strongly related to the concept of overfitting and underfitting.

# %% [markdown]
# 10. What is classification, exactly? What are the main distinctions between classification and regression?

# %% [markdown]
# Answer:
#
# In Machine Learning, classification is a predictive modeling problem that predicts a class label for an example of the input data. Classification predicts a discrete class label, while Regression predicts a continuous quantity. Classification predictive modeling is the process of comparing a mapping function (say, f) from the input variables X to the discrete output variables, y. The output variables are often referred to as labels or categories. A mapping function predicts a class or category for an observation. For example, an email can be classified as "spam" or "not spam".
#
# The main difference between Classification algorithm and Regression algorithm is that Regression algorithm is used to find the continuous values (like Price, Income, Age, etc.) whereas Classification algorithm is used to predict or classify the distinct values (like True or False, Male or Female, etc.).

# %% [markdown]
# 11. What is regression, and how does it work? Give an example of a real-world problem that was solved using regression.

# %% [markdown]
# Answer:
#
# Regression is a supervised machine learning technique for predicting continuous values. The goal of the regression algorithm is to create a best fit line or curve between the data. The three main metrics used to evaluate a trained regression model are variance, bias and error.
#
# For example, a simple linear regression in real life would be to find a relationship between weight and height of population with a sample size of weight as a dependent variable. For multiple variable regression, one could find a relationship between height, age and gender of population with respect to weight.

# %% [markdown]
# 12. Describe the clustering mechanism in detail.

# %% [markdown]
# Answer:
#
# Clustering involves the division of a population or data point into multiple subgroups, with the result that data points within the same subgroup are more homogeneous than data points within other subgroups.
#
# In the simplest terms, the goal is to separate groups with similar characteristics and assign them to clusters. The goal of grouping is to reduce a collection of abstract objects to a collection of similar objects.
#
# Clustering methods can be classified into the following categories:
#
# -> Partitioning Method
#
# -> Hierarchical Method
#
# -> Density-based Method
#
# -> Grid-Based Method
#
# -> Model-Based Method
#
# -> Constraint-based Method

# %% [markdown]
# <pre>
# 13. Make brief observations on two of the following topics:
# i. Machine learning algorithms are used
# ii. Studying under supervision
# iii. Studying without supervision
# iv. Reinforcement learning is a form of learning based on positive reinforcement.
#
# </pre>

# %% [markdown]
# Answer:
#
# - Studying without guidance is learning or learning without direct guidance. It encourages self-motivation and self-correcting by using metrics to make sure you're on the right track. But it also has its drawbacks, like slow progress and no guidance from a supervisor.
# - In mathematical terms, reinforcement learning needs rewards in order for the algorithm to make the right predictions and keep going to get better. If the predictions are wrong, it just slows the algorithm down because it has to keep giving penalties. So, the real progress of reinforcement learning is coming from positive reinforcement.
